# %% [markdown]
# ## [github](https://www.kaggle.com/kimjihoo/coronavirusdataset)에서 가져온 데이터 전처리

# %%
import sys
import os
from pathlib import Path

root = Path(os.getcwd()).parent.parent
sys.path.append(str(root))

# %%
import pandas as pd
import re

# %% [markdown]
# ### PatientRoute.csv

# %%
patient_route = pd.read_csv(os.path.join(root, 'data', 'raw', 'github', 'PatientRoute.csv'))
patient_route.head()
# Out:
#    patient_id  global_num        date     province          city  \
# 0  1000000001         2.0  2020-01-22  Gyeonggi-do      Gimpo-si
# 1  1000000001         2.0  2020-01-24        Seoul       Jung-gu
# 2  1000000002         5.0  2020-01-25        Seoul   Seongbuk-gu
# 3  1000000002         5.0  2020-01-26        Seoul   Seongbuk-gu
# 4  1000000002         5.0  2020-01-26        Seoul  Seongdong-gu
#
#                     type   latitude   longitude
# 0                airport  37.615246  126.715632
# 1               hospital  37.567241  127.005659
# 2                    etc  37.592560  127.017048
# 3                  store  37.591810  127.016822
# 4  public_transportation  37.563992  127.029534

# %% [markdown]
# ### PatientInfo.csv

# %%
patient_info = pd.read_csv(os.path.join(root, 'data', 'raw', 'github', 'PatientInfo.csv'))
patient_info.head()
# Out:
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001         2.0    male      1964.0  50s   Korea    Seoul
# 1  1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005         9.0  female      1992.0  20s   Korea    Seoul
#
#           city disease        infection_case  infection_order   infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow              1.0           NaN
# 1  Jungnang-gu     NaN       overseas inflow              1.0           NaN
# 2    Jongno-gu     NaN  contact with patient              2.0  2.002000e+09
# 3      Mapo-gu     NaN       overseas inflow              1.0           NaN
# 4  Seongbuk-gu     NaN  contact with patient              2.0  1.000000e+09
#
#    contact_number symptom_onset_date confirmed_date released_date  \
# 0            75.0         2020-01-22     2020-01-23    2020-02-05
# 1            31.0                NaN     2020-01-30    2020-03-02
# 2            17.0                NaN     2020-01-30    2020-02-19
# 3             9.0         2020-01-26     2020-01-30    2020-02-15
# 4             2.0                NaN     2020-01-31    2020-02-24
#
#   deceased_date     state
# 0           NaN  released
# 1           NaN  released
# 2           NaN  released
# 3           NaN  released
# 4           NaN  released

# %%
patient_info = patient_info[['patient_id', 'global_num', 'infection_case']]
patient_info.head()
# Out:
#    patient_id  global_num        infection_case
# 0  1000000001         2.0       overseas inflow
# 1  1000000002         5.0       overseas inflow
# 2  1000000003         6.0  contact with patient
# 3  1000000004         7.0       overseas inflow
# 4  1000000005         9.0  contact with patient

# %% [markdown]
# ### MergedRoute.csv

# %%
merged_route = pd.merge(patient_info, patient_route)
merged_route.head()
# Out:
#    patient_id  global_num   infection_case        date     province  \
# 0  1000000001         2.0  overseas inflow  2020-01-22  Gyeonggi-do
# 1  1000000001         2.0  overseas inflow  2020-01-24        Seoul
# 2  1000000002         5.0  overseas inflow  2020-01-25        Seoul
# 3  1000000002         5.0  overseas inflow  2020-01-26        Seoul
# 4  1000000002         5.0  overseas inflow  2020-01-26        Seoul
#
#            city                   type   latitude   longitude
# 0      Gimpo-si                airport  37.615246  126.715632
# 1       Jung-gu               hospital  37.567241  127.005659
# 2   Seongbuk-gu                    etc  37.592560  127.017048
# 3   Seongbuk-gu                  store  37.591810  127.016822
# 4  Seongdong-gu  public_transportation  37.563992  127.029534

# %%
# latitude, longitude → grid 정보
def to_grid(lat, lon):
    row = 256
    column = 256
    seoul_start_lat = 37.698098
    seoul_start_lon = 126.799791
    seoul_end_lat = 37.472494
    seoul_end_lon = 127.142928
    lat_distance = seoul_end_lat - seoul_start_lat 
    lon_distance = seoul_end_lon - seoul_start_lon

    if seoul_end_lat > lat or lat > seoul_start_lat:
        return -1, -1
    if seoul_start_lon > lon or lon > seoul_end_lon:
        return -1, -1

    lat_distance2= lat - seoul_start_lat
    lon_distance2 = lon - seoul_start_lon
    row = (lat_distance2 * 255) / lat_distance
    col = (lon_distance2 * 255) / lon_distance

    return int(row), int(col)

merged_route['row'] = ""
merged_route['col'] = ""

for i in range(len(merged_route)):
    latitude = merged_route['latitude'].values[i]
    longitude = merged_route['longitude'].values[i]
    row, col = to_grid(latitude, longitude)
    merged_route.iloc[i, merged_route.columns.get_loc('row')] = row
    merged_route.iloc[i, merged_route.columns.get_loc('col')] = col
    
merged_route.head()
# Out:
#    patient_id  global_num   infection_case        date     province  \
# 0  1000000001         2.0  overseas inflow  2020-01-22  Gyeonggi-do
# 1  1000000001         2.0  overseas inflow  2020-01-24        Seoul
# 2  1000000002         5.0  overseas inflow  2020-01-25        Seoul
# 3  1000000002         5.0  overseas inflow  2020-01-26        Seoul
# 4  1000000002         5.0  overseas inflow  2020-01-26        Seoul
#
#            city                   type   latitude   longitude  row  col
# 0      Gimpo-si                airport  37.615246  126.715632   -1   -1
# 1       Jung-gu               hospital  37.567241  127.005659  147  152
# 2   Seongbuk-gu                    etc  37.592560  127.017048  119  161
# 3   Seongbuk-gu                  store  37.591810  127.016822  120  161
# 4  Seongdong-gu  public_transportation  37.563992  127.029534  151  170

# %%
# 서울 아닌 확진자 방문지 제거, 필요 없는 columns 제거
merged_route = merged_route.loc[merged_route['row'] != -1]
merged_route = merged_route[['patient_id', 'city', 'infection_case', 'date', 'type', 'latitude', 'longitude', 'row', 'col']]
merged_route.head()
# Out:
#    patient_id          city   infection_case        date  \
# 1  1000000001       Jung-gu  overseas inflow  2020-01-24
# 2  1000000002   Seongbuk-gu  overseas inflow  2020-01-25
# 3  1000000002   Seongbuk-gu  overseas inflow  2020-01-26
# 4  1000000002  Seongdong-gu  overseas inflow  2020-01-26
# 5  1000000002   Seongbuk-gu  overseas inflow  2020-01-26
#
#                     type   latitude   longitude  row  col
# 1               hospital  37.567241  127.005659  147  152
# 2                    etc  37.592560  127.017048  119  161
# 3                  store  37.591810  127.016822  120  161
# 4  public_transportation  37.563992  127.029534  151  170
# 5  public_transportation  37.590330  127.015221  121  160

# %%
# city 형식에 맞게 변경
indices_to_del = []

for index, row in merged_route.iterrows():
    city = row['city']
    
    new_city = re.search(r'.*(?=-gu)', city)
    
    if new_city is None:
        indices_to_del.append(index)
        continue
        
    new_city = new_city.group().lower()
    merged_route.loc[index, 'city'] = new_city
    
for index in indices_to_del:
    merged_route = merged_route.drop(index=index)
    
merged_route = merged_route.reset_index(drop=True)
merged_route
# Out:
#       patient_id          city        infection_case        date  \
# 0     1000000001          jung       overseas inflow  2020-01-24
# 1     1000000002      seongbuk       overseas inflow  2020-01-25
# 2     1000000002      seongbuk       overseas inflow  2020-01-26
# 3     1000000002     seongdong       overseas inflow  2020-01-26
# 4     1000000002      seongbuk       overseas inflow  2020-01-26
# ...          ...           ...                   ...         ...
# 2502  6004000023  yeongdeungpo                   etc  2020-02-24
# 2503  6004000025          jung                   etc  2020-02-21
# 2504  6011000010          mapo  contact with patient  2020-02-19
# 2505  6023000011       dongjak                   NaN  2020-02-21
# 2506  6100000024      gangdong  contact with patient  2020-02-24
#
#                        type   latitude   longitude  row  col
# 0                  hospital  37.567241  127.005659  147  152
# 1                       etc  37.592560  127.017048  119  161
# 2                     store  37.591810  127.016822  120  161
# 3     public_transportation  37.563992  127.029534  151  170
# 4     public_transportation  37.590330  127.015221  121  160
# ...                     ...        ...         ...  ...  ...
# 2502               hospital  37.499847  126.911006  224   82
# 2503                    etc  37.566535  126.977969  148  132
# 2504                  store  37.551936  126.921668  165   90
# 2505               hospital  37.498990  126.937719  225  102
# 2506               pharmacy  37.533819  127.137649  185  251
#
# [2507 rows x 9 columns]

# %%
# 파일로 저장
path = os.path.join(root, 'data', 'extracted', 'MergedRoute.csv')
merged_route.to_csv(path, encoding='utf-8-sig', index=False)
